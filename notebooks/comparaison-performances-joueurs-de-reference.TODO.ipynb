# %% [markdown]
# # Comparaison de l'efficacité des joueurs RL classiques

# %%
#Imports
import sys
sys.path.append('../onitama/')
from players import HeuristicPlayer, RandomPlayer, LookAheadHeuristicPlayer, MCTSPlayer
from dl_players_v2 import CNNPlayer_v2
from game import GameSession
import pickle

# %%
cnn_v2_dropout_large = CNNPlayer_v2()
cnn_v2_dropout_large.load_weights('../saved-models/CNNPlayer-v1-withdropout-datalarge-dropout-weights.weights.h5')

#Configuration
players = {
    'random' : { 'class' : RandomPlayer(), 'name' : 'Joueur random', 'type' : 'random'},
    'heuristic_regular' : { 'class' : HeuristicPlayer(heuristic_function='heuristic_regular'), 'name' : 'Heuristique (regular)', 'type' : 'heuristic'},
    'heuristic_aggressive' : { 'class' : HeuristicPlayer(heuristic_function='heuristic_aggressive'), 'name' : 'Heuristique (aggressive)', 'type' : 'heuristic'},
    'heuristic_defensive' : { 'class' : HeuristicPlayer(heuristic_function='heuristic_defensive'), 'name' : 'Heuristique (defensive)', 'type' : 'heuristic'},
    'heuristic_mobility' : { 'class' : HeuristicPlayer(heuristic_function='heuristic_mobility'), 'name' : 'Heuristique (mobility)', 'type' : 'heuristic'},
    'heuristic_positional' : { 'class' : HeuristicPlayer(heuristic_function='heuristic_positional'), 'name' : 'Heuristique (positional)', 'type' : 'heuristic'},
     'heuristic_2lookahead_regular' : { 'class' : LookAheadHeuristicPlayer(max_depth=2, heuristic_function='heuristic_regular'), 'name' : 'LookAhead2 heuristique (regular)', 'type' : 'heuristic2'},
    'heuristic_2lookahead_aggressive' : { 'class' : LookAheadHeuristicPlayer(max_depth=2, heuristic_function='heuristic_aggressive'), 'name' : 'LookAhead2 heuristique (aggressive)', 'type' : 'heuristic2'},
    'heuristic_2lookahead_defensive' : { 'class' : LookAheadHeuristicPlayer(max_depth=2, heuristic_function='heuristic_defensive'), 'name' : 'LookAhead2 heuristique (defensive)', 'type' : 'heuristic2'},
    'heuristic_2lookahead_mobility' : { 'class' : LookAheadHeuristicPlayer(max_depth=2, heuristic_function='heuristic_mobility'), 'name' : 'LookAhead2 heuristique (mobility)', 'type' : 'heuristic2'},
    'heuristic_2lookahead_positional' : { 'class' : LookAheadHeuristicPlayer(max_depth=2, heuristic_function='heuristic_positional'), 'name' : 'LookAhead2 heuristique (positional)', 'type' : 'heuristic2'},
    'heuristic_3lookahead_regular' : { 'class' : LookAheadHeuristicPlayer(max_depth=3, heuristic_function='heuristic_regular'), 'name' : 'LookAhead3 heuristique (regular)', 'type' : 'heuristic3'},
    'heuristic_3lookahead_aggressive' : { 'class' : LookAheadHeuristicPlayer(max_depth=3, heuristic_function='heuristic_aggressive'), 'name' : 'LookAhead3 heuristique (aggressive)', 'type' : 'heuristic3'},
    'heuristic_3lookahead_defensive' : { 'class' : LookAheadHeuristicPlayer(max_depth=3, heuristic_function='heuristic_defensive'), 'name' : 'LookAhead3 heuristique (defensive)', 'type' : 'heuristic3'},
    'heuristic_3lookahead_mobility' : { 'class' : LookAheadHeuristicPlayer(max_depth=3, heuristic_function='heuristic_mobility'), 'name' : 'LookAhead3 heuristique (mobility)', 'type' : 'heuristic3'},
    'heuristic_3lookahead_positional' : { 'class' : LookAheadHeuristicPlayer(max_depth=3, heuristic_function='heuristic_positional'), 'name' : 'LookAhead3 heuristique (positional)', 'type' : 'heuristic3'}
}

type_colors = {
    'random' : 'grey',
    'heuristic' : 'deepskyblue',
    'heuristic2' : 'cornflowerblue',
    'heuristic3' : 'darkblue',
    'mcts' : 'gold',
    'dl' : 'red'
}
# Out:
# 2026-04-14 18:20:01.828204: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
#Résultats
resultats = {}

# %%
with open('resultats.pkl', 'rb') as f:
    resultats = pickle.load(f)

for key in ['montecarlo_1000', 'montecarlo_2000', 'cnn_v2_dropout_large']:
    resultats.pop(key, None)
    for p in resultats:
        resultats[p].pop(key, None)

# %%
resultats
# Out:
# {'random': {'heuristic_regular': {'win': 2,
#    'draw': 0,
#    'avg_time': np.float64(0.012718253968253967)},
#   'heuristic_aggressive': {'win': 6, 'draw': 0, 'avg_time': np.float64(0.002)},
#   'heuristic_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.005237484737484737)},
#   'heuristic_mobility': {'win': 3, 'draw': 0, 'avg_time': np.float64(0.002)},
#   'heuristic_positional': {'win': 4,
#    'draw': 0,
#    'avg_time': np.float64(0.010928571428571428)},
#   'heuristic_2lookahead_regular': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.010206099456099455)},
#   'heuristic_2lookahead_aggressive': {'win': 3,
#    'draw': 0,
#    'avg_time': np.float64(0.03802777777777778)},
#   'heuristic_2lookahead_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.032193748631829125)},
#   'heuristic_2lookahead_mobility': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.02722258297258297)},
#   'heuristic_2lookahead_positional': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.027706349206349207)},
#   'heuristic_3lookahead_regular': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.020516556972439322)},
#   'heuristic_3lookahead_aggressive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.017266233766233766)},
#   'heuristic_3lookahead_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.024935651622722557)},
#   'heuristic_3lookahead_mobility': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.02259325396825397)},
#   'heuristic_3lookahead_positional': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.01742763200851436)},
#   'mcts_1000': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.012679292929292929)},
#   'mcts_2000': {'win': 2,
#    'draw': 0,
#    'avg_time': np.float64(0.011688311688311687)}},
#  'heuristic_regular': {'random': {'win': 95,
#    'draw': 0,
#    'avg_time': np.float64(0.0945704834381305)},
#   'heuristic_aggressive': {'win': 44,
#    'draw': 0,
#    'avg_time': np.float64(0.07442460317460317)},
#   'heuristic_defensive': {'win': 23,
#    'draw': 3,
#    'avg_time': np.float64(0.0980923121150608)},
#   'heuristic_mobility': {'win': 60,
#    'draw': 0,
#    'avg_time': np.float64(0.08409102009102008)},
#   'heuristic_positional': {'win': 30,
#    'draw': 0,
#    'avg_time': np.float64(0.06387886498606311)},
#   'heuristic_2lookahead_regular': {'win': 4,
#    'draw': 0,
#    'avg_time': np.float64(0.1153872222548693)},
#   'heuristic_2lookahead_aggressive': {'win': 9,
#    'draw': 0,
#    'avg_time': np.float64(0.1286947117210275)},
#   'heuristic_2lookahead_defensive': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.15562601803828752)},
#   'heuristic_2lookahead_mobility': {'win': 5,
#    'draw': 0,
#    'avg_time': np.float64(0.11852956765456764)},
#   'heuristic_2lookahead_positional': {'win': 3,
#    'draw': 0,
#    'avg_time': np.float64(0.08580872722049192)},
#   'heuristic_3lookahead_regular': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.09962489591591758)},
#   'heuristic_3lookahead_aggressive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.09187933551123206)},
#   'heuristic_3lookahead_defensive': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.11969050361403304)},
#   'heuristic_3lookahead_mobility': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.0928313936063936)},
#   'heuristic_3lookahead_positional': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.1135761300428382)},
#   'mcts_1000': {'win': 51,
#    'draw': 0,
#    'avg_time': np.float64(0.0806629956552824)},
#   'mcts_2000': {'win': 57,
#    'draw': 0,
#    'avg_time': np.float64(0.1220876884553355)}},
#  'heuristic_aggressive': {'random': {'win': 90,
#    'draw': 0,
#    'avg_time': np.float64(0.0991031746031746)},
#   'heuristic_regular': {'win': 54,
#    'draw': 0,
#    'avg_time': np.float64(0.08968037518037518)},
#   'heuristic_defensive': {'win': 26,
#    'draw': 3,
#    'avg_time': np.float64(0.09119779525927729)},
#   'heuristic_mobility': {'win': 49,
#    'draw': 0,
#    'avg_time': np.float64(0.11867460317460317)},
#   'heuristic_positional': {'win': 39,
#    'draw': 0,
#    'avg_time': np.float64(0.09850068395656629)},
#   'heuristic_2lookahead_regular': {'win': 9,
#    'draw': 0,
#    'avg_time': np.float64(0.09163428337228646)},
#   'heuristic_2lookahead_aggressive': {'win': 11,
#    'draw': 0,
#    'avg_time': np.float64(0.12102669917801495)},
#   'heuristic_2lookahead_defensive': {'win': 4,
#    'draw': 0,
#    'avg_time': np.float64(0.12360563931290139)},
#   'heuristic_2lookahead_mobility': {'win': 13,
#    'draw': 0,
#    'avg_time': np.float64(0.14741844266844267)},
#   'heuristic_2lookahead_positional': {'win': 4,
#    'draw': 0,
#    'avg_time': np.float64(0.12228815890851495)},
#   'heuristic_3lookahead_regular': {'win': 0,
#    'draw': 3,
#    'avg_time': np.float64(0.1308412002241488)},
#   'heuristic_3lookahead_aggressive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.098029761015745)},
#   'heuristic_3lookahead_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.1401921982801133)},
#   'heuristic_3lookahead_mobility': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.1447623969168087)},
#   'heuristic_3lookahead_positional': {'win': 1,
#    'draw': 3,
#    'avg_time': np.float64(0.11109373200329083)},
#   'mcts_1000': {'win': 53,
#    'draw': 0,
#    'avg_time': np.float64(0.2053348318348318)},
#   'mcts_2000': {'win': 61,
#    'draw': 0,
#    'avg_time': np.float64(0.19900522729614803)}},
#  'heuristic_defensive': {'random': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(0.143900000382759)},
#   'heuristic_regular': {'win': 66,
#    'draw': 0,
#    'avg_time': np.float64(0.10845658557871614)},
#   'heuristic_aggressive': {'win': 79,
#    'draw': 0,
#    'avg_time': np.float64(0.0849944857926955)},
#   'heuristic_mobility': {'win': 73,
#    'draw': 2,
#    'avg_time': np.float64(0.08599904035576379)},
#   'heuristic_positional': {'win': 64,
#    'draw': 2,
#    'avg_time': np.float64(0.07172798138726681)},
#   'heuristic_2lookahead_regular': {'win': 13,
#    'draw': 1,
#    'avg_time': np.float64(0.09365030569770333)},
#   'heuristic_2lookahead_aggressive': {'win': 10,
#    'draw': 0,
#    'avg_time': np.float64(0.11503629762033547)},
#   'heuristic_2lookahead_defensive': {'win': 1,
#    'draw': 3,
#    'avg_time': np.float64(0.10962805796229742)},
#   'heuristic_2lookahead_mobility': {'win': 18,
#    'draw': 0,
#    'avg_time': np.float64(0.11149632629152753)},
#   'heuristic_2lookahead_positional': {'win': 8,
#    'draw': 0,
#    'avg_time': np.float64(0.10013832223718254)},
#   'heuristic_3lookahead_regular': {'win': 2,
#    'draw': 2,
#    'avg_time': np.float64(0.10377246230927437)},
#   'heuristic_3lookahead_aggressive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.10053538597489642)},
#   'heuristic_3lookahead_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.14037082688082203)},
#   'heuristic_3lookahead_mobility': {'win': 0,
#    'draw': 1,
#    'avg_time': np.float64(0.14915664311679927)},
#   'heuristic_3lookahead_positional': {'win': 0,
#    'draw': 4,
#    'avg_time': np.float64(0.1154308945478899)},
#   'mcts_1000': {'win': 83,
#    'draw': 0,
#    'avg_time': np.float64(0.11266464027029041)},
#   'mcts_2000': {'win': 95,
#    'draw': 0,
#    'avg_time': np.float64(0.12385983310635011)}},
#  'heuristic_mobility': {'random': {'win': 94,
#    'draw': 0,
#    'avg_time': np.float64(0.22441926263700457)},
#   'heuristic_regular': {'win': 48,
#    'draw': 0,
#    'avg_time': np.float64(0.17379870129870129)},
#   'heuristic_aggressive': {'win': 47,
#    'draw': 0,
#    'avg_time': np.float64(0.17053210678210678)},
#   'heuristic_defensive': {'win': 19,
#    'draw': 3,
#    'avg_time': np.float64(0.16050824424467813)},
#   'heuristic_positional': {'win': 33,
#    'draw': 0,
#    'avg_time': np.float64(0.15145331057831057)},
#   'heuristic_2lookahead_regular': {'win': 8,
#    'draw': 0,
#    'avg_time': np.float64(0.22206057831057827)},
#   'heuristic_2lookahead_aggressive': {'win': 5,
#    'draw': 0,
#    'avg_time': np.float64(0.1701441058941059)},
#   'heuristic_2lookahead_defensive': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.17920329507094215)},
#   'heuristic_2lookahead_mobility': {'win': 5,
#    'draw': 0,
#    'avg_time': np.float64(0.2200218947718948)},
#   'heuristic_2lookahead_positional': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.20284426684426685)},
#   'heuristic_3lookahead_regular': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.1961307108856577)},
#   'heuristic_3lookahead_aggressive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.19387152520681933)},
#   'heuristic_3lookahead_defensive': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.16756532356532358)},
#   'heuristic_3lookahead_mobility': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(0.21703540903540902)},
#   'heuristic_3lookahead_positional': {'win': 0,
#    'draw': 1,
#    'avg_time': np.float64(0.185775745782113)},
#   'mcts_1000': {'win': 58,
#    'draw': 0,
#    'avg_time': np.float64(0.20280423085686244)},
#   'mcts_2000': {'win': 70,
#    'draw': 0,
#    'avg_time': np.float64(0.18487056407644645)}},
#  'heuristic_positional': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(0.12797763347763344)},
#   'heuristic_regular': {'win': 63,
#    'draw': 0,
#    'avg_time': np.float64(0.12394658898033512)},
#   'heuristic_aggressive': {'win': 62,
#    'draw': 0,
#    'avg_time': np.float64(0.13192457542457542)},
#   'heuristic_defensive': {'win': 32,
#    'draw': 5,
#    'avg_time': np.float64(0.09784551206729325)},
#   'heuristic_mobility': {'win': 69,
#    'draw': 0,
#    'avg_time': np.float64(0.12101689976689978)},
#   'heuristic_2lookahead_regular': {'win': 21,
#    'draw': 1,
#    'avg_time': np.float64(0.1344178531356964)},
#   'heuristic_2lookahead_aggressive': {'win': 11,
#    'draw': 0,
#    'avg_time': np.float64(0.12922378030466267)},
#   'heuristic_2lookahead_defensive': {'win': 2,
#    'draw': 0,
#    'avg_time': np.float64(0.12811194755375854)},
#   'heuristic_2lookahead_mobility': {'win': 12,
#    'draw': 0,
#    'avg_time': np.float64(0.1429044591029885)},
#   'heuristic_2lookahead_positional': {'win': 5,
#    'draw': 0,
#    'avg_time': np.float64(0.14554908696021226)},
#   'heuristic_3lookahead_regular': {'win': 3,
#    'draw': 0,
#    'avg_time': np.float64(0.14408690704866164)},
#   'heuristic_3lookahead_aggressive': {'win': 1,
#    'draw': 2,
#    'avg_time': np.float64(0.11315995944237633)},
#   'heuristic_3lookahead_defensive': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(0.12404339201875882)},
#   'heuristic_3lookahead_mobility': {'win': 1,
#    'draw': 1,
#    'avg_time': np.float64(0.12037220195168773)},
#   'heuristic_3lookahead_positional': {'win': 1,
#    'draw': 1,
#    'avg_time': np.float64(0.1310148980878083)},
#   'mcts_1000': {'win': 76,
#    'draw': 0,
#    'avg_time': np.float64(0.15061920024420025)},
#   'mcts_2000': {'win': 90,
#    'draw': 0,
#    'avg_time': np.float64(0.13051978576978576)}},
#  'heuristic_2lookahead_regular': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(20.12746685259185)},
#   'heuristic_regular': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(18.022241916994776)},
#   'heuristic_aggressive': {'win': 90,
#    'draw': 0,
#    'avg_time': np.float64(17.89597877204495)},
#   'heuristic_defensive': {'win': 86,
#    'draw': 2,
#    'avg_time': np.float64(17.90143782846897)},
#   'heuristic_mobility': {'win': 93,
#    'draw': 0,
#    'avg_time': np.float64(17.774950089942735)},
#   'heuristic_positional': {'win': 85,
#    'draw': 0,
#    'avg_time': np.float64(16.874243671447232)},
#   'heuristic_2lookahead_aggressive': {'win': 45,
#    'draw': 0,
#    'avg_time': np.float64(20.03779931179931)},
#   'heuristic_2lookahead_defensive': {'win': 20,
#    'draw': 2,
#    'avg_time': np.float64(18.637418636962046)},
#   'heuristic_2lookahead_mobility': {'win': 48,
#    'draw': 0,
#    'avg_time': np.float64(21.053375676698753)},
#   'heuristic_2lookahead_positional': {'win': 40,
#    'draw': 2,
#    'avg_time': np.float64(19.721795460567986)},
#   'heuristic_3lookahead_regular': {'win': 5,
#    'draw': 29,
#    'avg_time': np.float64(16.82153704286271)},
#   'heuristic_3lookahead_aggressive': {'win': 4,
#    'draw': 3,
#    'avg_time': np.float64(16.896229042261346)},
#   'heuristic_3lookahead_defensive': {'win': 7,
#    'draw': 15,
#    'avg_time': np.float64(16.460638529746564)},
#   'heuristic_3lookahead_mobility': {'win': 3,
#    'draw': 17,
#    'avg_time': np.float64(27.71537376526869)},
#   'heuristic_3lookahead_positional': {'win': 3,
#    'draw': 24,
#    'avg_time': np.float64(29.77385543094176)},
#   'mcts_1000': {'win': 91,
#    'draw': 0,
#    'avg_time': np.float64(32.074975283525795)},
#   'mcts_2000': {'win': 89,
#    'draw': 0,
#    'avg_time': np.float64(33.70370836404738)}},
#  'heuristic_2lookahead_aggressive': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(21.15489894827395)},
#   'heuristic_regular': {'win': 96,
#    'draw': 0,
#    'avg_time': np.float64(18.599088429114744)},
#   'heuristic_aggressive': {'win': 95,
#    'draw': 0,
#    'avg_time': np.float64(17.957593156843156)},
#   'heuristic_defensive': {'win': 93,
#    'draw': 0,
#    'avg_time': np.float64(19.171068112265264)},
#   'heuristic_mobility': {'win': 94,
#    'draw': 0,
#    'avg_time': np.float64(18.66082153957154)},
#   'heuristic_positional': {'win': 91,
#    'draw': 1,
#    'avg_time': np.float64(19.239727831808715)},
#   'heuristic_2lookahead_regular': {'win': 61,
#    'draw': 1,
#    'avg_time': np.float64(22.18153661026297)},
#   'heuristic_2lookahead_defensive': {'win': 35,
#    'draw': 1,
#    'avg_time': np.float64(19.257760382179995)},
#   'heuristic_2lookahead_mobility': {'win': 52,
#    'draw': 1,
#    'avg_time': np.float64(20.03132902224195)},
#   'heuristic_2lookahead_positional': {'win': 43,
#    'draw': 0,
#    'avg_time': np.float64(20.708226826253032)},
#   'heuristic_3lookahead_regular': {'win': 25,
#    'draw': 4,
#    'avg_time': np.float64(19.477118853374993)},
#   'heuristic_3lookahead_aggressive': {'win': 7,
#    'draw': 4,
#    'avg_time': np.float64(16.218438221588922)},
#   'heuristic_3lookahead_defensive': {'win': 15,
#    'draw': 4,
#    'avg_time': np.float64(17.885521445389415)},
#   'heuristic_3lookahead_mobility': {'win': 20,
#    'draw': 10,
#    'avg_time': np.float64(23.20601130789495)},
#   'heuristic_3lookahead_positional': {'win': 22,
#    'draw': 6,
#    'avg_time': np.float64(19.427977440703966)},
#   'mcts_1000': {'win': 94,
#    'draw': 0,
#    'avg_time': np.float64(21.1101949023199)},
#   'mcts_2000': {'win': 95,
#    'draw': 0,
#    'avg_time': np.float64(21.309561324296624)}},
#  'heuristic_2lookahead_defensive': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(19.730240753398647)},
#   'heuristic_regular': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(18.09659464202808)},
#   'heuristic_aggressive': {'win': 98,
#    'draw': 0,
#    'avg_time': np.float64(17.872454073704073)},
#   'heuristic_defensive': {'win': 98,
#    'draw': 1,
#    'avg_time': np.float64(20.93008670624623)},
#   'heuristic_mobility': {'win': 98,
#    'draw': 0,
#    'avg_time': np.float64(19.691472804972804)},
#   'heuristic_positional': {'win': 98,
#    'draw': 1,
#    'avg_time': np.float64(20.63354526237229)},
#   'heuristic_2lookahead_regular': {'win': 83,
#    'draw': 3,
#    'avg_time': np.float64(19.90543495649458)},
#   'heuristic_2lookahead_aggressive': {'win': 59,
#    'draw': 4,
#    'avg_time': np.float64(19.812524156842542)},
#   'heuristic_2lookahead_mobility': {'win': 75,
#    'draw': 1,
#    'avg_time': np.float64(20.785224299092718)},
#   'heuristic_2lookahead_positional': {'win': 47,
#    'draw': 4,
#    'avg_time': np.float64(21.20889585841634)},
#   'heuristic_3lookahead_regular': {'win': 26,
#    'draw': 17,
#    'avg_time': np.float64(18.750992086164075)},
#   'heuristic_3lookahead_aggressive': {'win': 7,
#    'draw': 8,
#    'avg_time': np.float64(18.88146946894203)},
#   'heuristic_3lookahead_defensive': {'win': 16,
#    'draw': 23,
#    'avg_time': np.float64(19.171674683616505)},
#   'heuristic_3lookahead_mobility': {'win': 12,
#    'draw': 23,
#    'avg_time': np.float64(21.894540504094625)},
#   'heuristic_3lookahead_positional': {'win': 15,
#    'draw': 37,
#    'avg_time': np.float64(22.362351234962784)},
#   'mcts_1000': {'win': 97,
#    'draw': 0,
#    'avg_time': np.float64(19.911114466871275)},
#   'mcts_2000': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(20.456983225838492)}},
#  'heuristic_2lookahead_mobility': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(43.793391552891556)},
#   'heuristic_regular': {'win': 92,
#    'draw': 0,
#    'avg_time': np.float64(38.43847692748428)},
#   'heuristic_aggressive': {'win': 94,
#    'draw': 0,
#    'avg_time': np.float64(37.77881124267889)},
#   'heuristic_defensive': {'win': 89,
#    'draw': 0,
#    'avg_time': np.float64(38.88088590570579)},
#   'heuristic_mobility': {'win': 96,
#    'draw': 0,
#    'avg_time': np.float64(36.56640295815296)},
#   'heuristic_positional': {'win': 89,
#    'draw': 0,
#    'avg_time': np.float64(37.30441777244308)},
#   'heuristic_2lookahead_regular': {'win': 56,
#    'draw': 0,
#    'avg_time': np.float64(43.42042016717946)},
#   'heuristic_2lookahead_aggressive': {'win': 47,
#    'draw': 0,
#    'avg_time': np.float64(44.64470212499918)},
#   'heuristic_2lookahead_defensive': {'win': 33,
#    'draw': 2,
#    'avg_time': np.float64(40.27362775528413)},
#   'heuristic_2lookahead_positional': {'win': 47,
#    'draw': 0,
#    'avg_time': np.float64(43.45804227209838)},
#   'heuristic_3lookahead_regular': {'win': 14,
#    'draw': 3,
#    'avg_time': np.float64(33.090654418125744)},
#   'heuristic_3lookahead_aggressive': {'win': 1,
#    'draw': 2,
#    'avg_time': np.float64(36.752241744350165)},
#   'heuristic_3lookahead_defensive': {'win': 8,
#    'draw': 7,
#    'avg_time': np.float64(37.289359733533324)},
#   'heuristic_3lookahead_mobility': {'win': 12,
#    'draw': 1,
#    'avg_time': np.float64(36.86463601809787)},
#   'heuristic_3lookahead_positional': {'win': 9,
#    'draw': 10,
#    'avg_time': np.float64(33.462944510873065)},
#   'mcts_1000': {'win': 95,
#    'draw': 0,
#    'avg_time': np.float64(39.789284157105364)},
#   'mcts_2000': {'win': 89,
#    'draw': 0,
#    'avg_time': np.float64(41.8761718004218)}},
#  'heuristic_2lookahead_positional': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(30.284420388009263)},
#   'heuristic_regular': {'win': 96,
#    'draw': 0,
#    'avg_time': np.float64(28.51814372990719)},
#   'heuristic_aggressive': {'win': 91,
#    'draw': 0,
#    'avg_time': np.float64(27.85561689188005)},
#   'heuristic_defensive': {'win': 92,
#    'draw': 0,
#    'avg_time': np.float64(31.66368664006851)},
#   'heuristic_mobility': {'win': 96,
#    'draw': 0,
#    'avg_time': np.float64(28.040009874112812)},
#   'heuristic_positional': {'win': 93,
#    'draw': 1,
#    'avg_time': np.float64(27.068573431115627)},
#   'heuristic_2lookahead_regular': {'win': 61,
#    'draw': 0,
#    'avg_time': np.float64(31.594912035447386)},
#   'heuristic_2lookahead_aggressive': {'win': 52,
#    'draw': 1,
#    'avg_time': np.float64(32.08002901111616)},
#   'heuristic_2lookahead_defensive': {'win': 41,
#    'draw': 3,
#    'avg_time': np.float64(32.26820054095218)},
#   'heuristic_2lookahead_mobility': {'win': 62,
#    'draw': 0,
#    'avg_time': np.float64(32.02902474378906)},
#   'heuristic_3lookahead_regular': {'win': 30,
#    'draw': 12,
#    'avg_time': np.float64(28.1291303582764)},
#   'heuristic_3lookahead_aggressive': {'win': 7,
#    'draw': 2,
#    'avg_time': np.float64(28.157684502804564)},
#   'heuristic_3lookahead_defensive': {'win': 16,
#    'draw': 12,
#    'avg_time': np.float64(29.178416524418036)},
#   'heuristic_3lookahead_mobility': {'win': 17,
#    'draw': 13,
#    'avg_time': np.float64(31.737310857544845)},
#   'heuristic_3lookahead_positional': {'win': 12,
#    'draw': 18,
#    'avg_time': np.float64(31.15221905024988)},
#   'mcts_1000': {'win': 97,
#    'draw': 0,
#    'avg_time': np.float64(31.541681164726374)},
#   'mcts_2000': {'win': 96,
#    'draw': 0,
#    'avg_time': np.float64(29.288749944499944)}},
#  'heuristic_3lookahead_regular': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(256.1038149211899)},
#   'heuristic_regular': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(234.01802813172432)},
#   'heuristic_aggressive': {'win': 98,
#    'draw': 2,
#    'avg_time': np.float64(236.89549403191296)},
#   'heuristic_defensive': {'win': 98,
#    'draw': 0,
#    'avg_time': np.float64(235.34914203800517)},
#   'heuristic_mobility': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(241.07289907083657)},
#   'heuristic_positional': {'win': 97,
#    'draw': 1,
#    'avg_time': np.float64(219.8982197160412)},
#   'heuristic_2lookahead_regular': {'win': 74,
#    'draw': 18,
#    'avg_time': np.float64(262.84932610770176)},
#   'heuristic_2lookahead_aggressive': {'win': 61,
#    'draw': 6,
#    'avg_time': np.float64(260.3895859905446)},
#   'heuristic_2lookahead_defensive': {'win': 65,
#    'draw': 11,
#    'avg_time': np.float64(254.6960587957384)},
#   'heuristic_2lookahead_mobility': {'win': 85,
#    'draw': 2,
#    'avg_time': np.float64(254.2313144683931)},
#   'heuristic_2lookahead_positional': {'win': 64,
#    'draw': 8,
#    'avg_time': np.float64(291.88411127523904)},
#   'heuristic_3lookahead_aggressive': {'win': 28,
#    'draw': 6,
#    'avg_time': np.float64(240.5019417287888)},
#   'heuristic_3lookahead_defensive': {'win': 28,
#    'draw': 8,
#    'avg_time': np.float64(223.32680940192492)},
#   'heuristic_3lookahead_mobility': {'win': 31,
#    'draw': 5,
#    'avg_time': np.float64(294.0383532314105)},
#   'heuristic_3lookahead_positional': {'win': 35,
#    'draw': 22,
#    'avg_time': np.float64(285.807465335356)},
#   'mcts_1000': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(256.0107491179701)},
#   'mcts_2000': {'win': 96,
#    'draw': 0,
#    'avg_time': np.float64(247.8241813424364)}},
#  'heuristic_3lookahead_aggressive': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(304.42644096181596)},
#   'heuristic_regular': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(270.0192504203313)},
#   'heuristic_aggressive': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(276.8377148033761)},
#   'heuristic_defensive': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(351.17509097504865)},
#   'heuristic_mobility': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(278.0162402842256)},
#   'heuristic_positional': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(236.62442173966232)},
#   'heuristic_2lookahead_regular': {'win': 94,
#    'draw': 2,
#    'avg_time': np.float64(277.2157946102015)},
#   'heuristic_2lookahead_aggressive': {'win': 83,
#    'draw': 5,
#    'avg_time': np.float64(258.31540009018386)},
#   'heuristic_2lookahead_defensive': {'win': 82,
#    'draw': 7,
#    'avg_time': np.float64(327.2779587935468)},
#   'heuristic_2lookahead_mobility': {'win': 97,
#    'draw': 1,
#    'avg_time': np.float64(315.4558595557386)},
#   'heuristic_2lookahead_positional': {'win': 87,
#    'draw': 6,
#    'avg_time': np.float64(305.96000686164973)},
#   'heuristic_3lookahead_regular': {'win': 68,
#    'draw': 2,
#    'avg_time': np.float64(254.5734060397169)},
#   'heuristic_3lookahead_defensive': {'win': 54,
#    'draw': 16,
#    'avg_time': np.float64(225.87443112771035)},
#   'heuristic_3lookahead_mobility': {'win': 57,
#    'draw': 5,
#    'avg_time': np.float64(278.8463994715215)},
#   'heuristic_3lookahead_positional': {'win': 55,
#    'draw': 8,
#    'avg_time': np.float64(382.6984156976577)},
#   'mcts_1000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(499.05791853979355)},
#   'mcts_2000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(376.56401257810825)}},
#  'heuristic_3lookahead_defensive': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(279.96429948646124)},
#   'heuristic_regular': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(227.3250481147829)},
#   'heuristic_aggressive': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(251.8242472811488)},
#   'heuristic_defensive': {'win': 98,
#    'draw': 0,
#    'avg_time': np.float64(291.7369339627019)},
#   'heuristic_mobility': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(242.9298747918748)},
#   'heuristic_positional': {'win': 98,
#    'draw': 2,
#    'avg_time': np.float64(237.843672253961)},
#   'heuristic_2lookahead_regular': {'win': 77,
#    'draw': 19,
#    'avg_time': np.float64(260.8205709110041)},
#   'heuristic_2lookahead_aggressive': {'win': 81,
#    'draw': 0,
#    'avg_time': np.float64(249.79844512258478)},
#   'heuristic_2lookahead_defensive': {'win': 70,
#    'draw': 14,
#    'avg_time': np.float64(255.44965499743566)},
#   'heuristic_2lookahead_mobility': {'win': 84,
#    'draw': 3,
#    'avg_time': np.float64(275.35220293238734)},
#   'heuristic_2lookahead_positional': {'win': 76,
#    'draw': 14,
#    'avg_time': np.float64(309.41065224621013)},
#   'heuristic_3lookahead_regular': {'win': 58,
#    'draw': 11,
#    'avg_time': np.float64(197.44456581107724)},
#   'heuristic_3lookahead_aggressive': {'win': 34,
#    'draw': 13,
#    'avg_time': np.float64(218.75594741421864)},
#   'heuristic_3lookahead_mobility': {'win': 40,
#    'draw': 27,
#    'avg_time': np.float64(303.1511856577496)},
#   'heuristic_3lookahead_positional': {'win': 33,
#    'draw': 40,
#    'avg_time': np.float64(498.9167655821313)},
#   'mcts_1000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(508.93420726401223)},
#   'mcts_2000': {'win': 99,
#    'draw': 0,
#    'avg_time': np.float64(444.8741438422687)}},
#  'heuristic_3lookahead_mobility': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(1253.4771866717515)},
#   'heuristic_regular': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(880.0098161139265)},
#   'heuristic_aggressive': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(850.5452337053044)},
#   'heuristic_defensive': {'win': 97,
#    'draw': 0,
#    'avg_time': np.float64(962.756448901106)},
#   'heuristic_mobility': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(747.6249009038346)},
#   'heuristic_positional': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(770.5077279744958)},
#   'heuristic_2lookahead_regular': {'win': 88,
#    'draw': 10,
#    'avg_time': np.float64(1142.44653856743)},
#   'heuristic_2lookahead_aggressive': {'win': 73,
#    'draw': 7,
#    'avg_time': np.float64(585.9623531095507)},
#   'heuristic_2lookahead_defensive': {'win': 58,
#    'draw': 22,
#    'avg_time': np.float64(831.3116733944465)},
#   'heuristic_2lookahead_mobility': {'win': 88,
#    'draw': 3,
#    'avg_time': np.float64(646.3008221625511)},
#   'heuristic_2lookahead_positional': {'win': 68,
#    'draw': 19,
#    'avg_time': np.float64(756.1504022037547)},
#   'heuristic_3lookahead_regular': {'win': 54,
#    'draw': 13,
#    'avg_time': np.float64(591.8818374040178)},
#   'heuristic_3lookahead_aggressive': {'win': 24,
#    'draw': 3,
#    'avg_time': np.float64(606.4213269413301)},
#   'heuristic_3lookahead_defensive': {'win': 25,
#    'draw': 26,
#    'avg_time': np.float64(676.9558683967828)},
#   'heuristic_3lookahead_positional': {'win': 34,
#    'draw': 39,
#    'avg_time': np.float64(797.6004971129732)},
#   'mcts_1000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(609.9198416786924)},
#   'mcts_2000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(1005.6751455401325)}},
#  'heuristic_3lookahead_positional': {'random': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(757.1494097644365)},
#   'heuristic_regular': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(627.807456083309)},
#   'heuristic_aggressive': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(695.4617475079193)},
#   'heuristic_defensive': {'win': 98,
#    'draw': 2,
#    'avg_time': np.float64(773.7875851478211)},
#   'heuristic_mobility': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(672.4583610833612)},
#   'heuristic_positional': {'win': 94,
#    'draw': 2,
#    'avg_time': np.float64(659.86600508523)},
#   'heuristic_2lookahead_regular': {'win': 84,
#    'draw': 15,
#    'avg_time': np.float64(732.821768915289)},
#   'heuristic_2lookahead_aggressive': {'win': 69,
#    'draw': 10,
#    'avg_time': np.float64(660.8130605476099)},
#   'heuristic_2lookahead_defensive': {'win': 51,
#    'draw': 38,
#    'avg_time': np.float64(808.5045751057858)},
#   'heuristic_2lookahead_mobility': {'win': 90,
#    'draw': 3,
#    'avg_time': np.float64(381.537613801385)},
#   'heuristic_2lookahead_positional': {'win': 65,
#    'draw': 18,
#    'avg_time': np.float64(469.20818236833935)},
#   'heuristic_3lookahead_regular': {'win': 45,
#    'draw': 19,
#    'avg_time': np.float64(323.93112675062685)},
#   'heuristic_3lookahead_aggressive': {'win': 34,
#    'draw': 13,
#    'avg_time': np.float64(467.210015099512)},
#   'heuristic_3lookahead_defensive': {'win': 17,
#    'draw': 53,
#    'avg_time': np.float64(496.3679841531204)},
#   'heuristic_3lookahead_mobility': {'win': 19,
#    'draw': 50,
#    'avg_time': np.float64(487.5558353085609)},
#   'mcts_1000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(469.8916998155507)},
#   'mcts_2000': {'win': 100,
#    'draw': 0,
#    'avg_time': np.float64(453.2962655724049)}},
#  'mcts_1000': {'random': {'win': 97,
#    'draw': 0,
#    'avg_time': np.float64(422.9572217797579)},
#   'heuristic_regular': {'win': 40,
#    'draw': 0,
#    'avg_time': np.float64(418.90218282244723)},
#   'heuristic_aggressive': {'win': 41,
#    'draw': 0,
#    'avg_time': np.float64(386.74559068709067)},
#   'heuristic_defensive': {'win': 16,
#    'draw': 0,
#    'avg_time': np.float64(350.37403176500425)},
#   'heuristic_mobility': {'win': 46,
#    'draw': 0,
#    'avg_time': np.float64(392.5300289987791)},
#   'heuristic_positional': {'win': 20,
#    'draw': 0,
#    'avg_time': np.float64(488.62044790903116)},
#   'heuristic_2lookahead_regular': {'win': 7,
#    'draw': 0,
#    'avg_time': np.float64(388.5037534186949)},
#   'heuristic_2lookahead_aggressive': {'win': 5,
#    'draw': 0,
#    'avg_time': np.float64(377.8268587971197)},
#   'heuristic_2lookahead_defensive': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(330.74231836789914)},
#   'heuristic_2lookahead_mobility': {'win': 3,
#    'draw': 0,
#    'avg_time': np.float64(304.04058757128064)},
#   'heuristic_2lookahead_positional': {'win': 6,
#    'draw': 0,
#    'avg_time': np.float64(320.43495510264586)},
#   'heuristic_3lookahead_regular': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(304.9355307270244)},
#   'heuristic_3lookahead_aggressive': {'win': 2,
#    'draw': 0,
#    'avg_time': np.float64(306.0071637267961)},
#   'heuristic_3lookahead_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(317.212775214079)},
#   'heuristic_3lookahead_mobility': {'win': 1,
#    'draw': 0,
#    'avg_time': np.float64(294.7298199768068)},
#   'heuristic_3lookahead_positional': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(317.04612802627366)},
#   'mcts_2000': {'win': 57,
#    'draw': 0,
#    'avg_time': np.float64(311.11948823600915)}},
#  'mcts_2000': {'random': {'win': 95,
#    'draw': 0,
#    'avg_time': np.float64(646.2732706132091)},
#   'heuristic_regular': {'win': 33,
#    'draw': 0,
#    'avg_time': np.float64(600.1396572074984)},
#   'heuristic_aggressive': {'win': 42,
#    'draw': 0,
#    'avg_time': np.float64(590.1967823842823)},
#   'heuristic_defensive': {'win': 4,
#    'draw': 0,
#    'avg_time': np.float64(612.9721481024247)},
#   'heuristic_mobility': {'win': 32,
#    'draw': 0,
#    'avg_time': np.float64(587.2054642857144)},
#   'heuristic_positional': {'win': 7,
#    'draw': 0,
#    'avg_time': np.float64(618.4125404791287)},
#   'heuristic_2lookahead_regular': {'win': 10,
#    'draw': 0,
#    'avg_time': np.float64(599.2427093189319)},
#   'heuristic_2lookahead_aggressive': {'win': 5,
#    'draw': 0,
#    'avg_time': np.float64(592.9653314324564)},
#   'heuristic_2lookahead_defensive': {'win': 3,
#    'draw': 0,
#    'avg_time': np.float64(612.4330828985686)},
#   'heuristic_2lookahead_mobility': {'win': 9,
#    'draw': 0,
#    'avg_time': np.float64(593.1896885442987)},
#   'heuristic_2lookahead_positional': {'win': 4,
#    'draw': 0,
#    'avg_time': np.float64(600.8593343323344)},
#   'heuristic_3lookahead_regular': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(618.2530433075696)},
#   'heuristic_3lookahead_aggressive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(616.4138204865741)},
#   'heuristic_3lookahead_defensive': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(623.2153239815739)},
#   'heuristic_3lookahead_mobility': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(596.202242372007)},
#   'heuristic_3lookahead_positional': {'win': 0,
#    'draw': 0,
#    'avg_time': np.float64(621.7210050626711)},
#   'mcts_1000': {'win': 42,
#    'draw': 0,
#    'avg_time': np.float64(635.2238129710154)}}}

# %%
nb_games = 100

for tested_player in players:

    if tested_player not in resultats:
        resultats[tested_player] = {}

    for p in players:
        
        if p != tested_player and p not in resultats[tested_player]:
            print(f"Joueur {tested_player} contre joueur {p}")
            p1 = players[tested_player]['class']
            p2 = players[p]['class']      
            gameSession = GameSession(player_one=p1, player_two=p2, number_of_games=nb_games)
            gameSession.start()

            stats = gameSession.getStats()
            
            resultats[tested_player][p] = {'win' : stats['p1_win'], 'draw' : stats['draw'], 'avg_time': stats['p1_avg_time']}



with open('resultats.pkl', 'wb') as f:
    pickle.dump(resultats, f)
# Out:
# Joueur heuristic_2lookahead_regular contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [03:58<00:00,  2.39s/it]
# Joueur heuristic_2lookahead_aggressive contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [02:37<00:00,  1.58s/it]
# Joueur heuristic_2lookahead_aggressive contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [04:53<00:00,  2.94s/it]
# Joueur heuristic_2lookahead_defensive contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [03:02<00:00,  1.83s/it]
# Joueur heuristic_2lookahead_defensive contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [05:01<00:00,  3.01s/it]
# Joueur heuristic_2lookahead_mobility contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [02:57<00:00,  1.77s/it]
# Joueur heuristic_2lookahead_mobility contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [04:45<00:00,  2.85s/it]
# Joueur heuristic_2lookahead_positional contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [02:38<00:00,  1.58s/it]
# Joueur heuristic_2lookahead_positional contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [04:18<00:00,  2.59s/it]
# Joueur heuristic_3lookahead_regular contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [05:34<00:00,  3.34s/it]
# Joueur heuristic_3lookahead_regular contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [06:10<00:00,  3.71s/it]
# Joueur heuristic_3lookahead_aggressive contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [04:49<00:00,  2.90s/it]
# Joueur heuristic_3lookahead_aggressive contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [06:28<00:00,  3.88s/it]
# Joueur heuristic_3lookahead_defensive contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [05:14<00:00,  3.14s/it]
# Joueur heuristic_3lookahead_defensive contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [04:31<00:00,  2.72s/it]
# Joueur heuristic_3lookahead_mobility contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [05:46<00:00,  3.46s/it]
# Joueur heuristic_3lookahead_mobility contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [05:24<00:00,  3.24s/it]
# Joueur heuristic_3lookahead_positional contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [03:42<00:00,  2.22s/it]
# Joueur heuristic_3lookahead_positional contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [06:34<00:00,  3.95s/it]
# Joueur montecarlo_1000 contre joueur random
# Games  : 100%|██████████| 100/100 [06:26<00:00,  3.87s/it]
# Joueur montecarlo_1000 contre joueur heuristic_regular
# Games  : 100%|██████████| 100/100 [01:31<00:00,  1.10it/s]
# Joueur montecarlo_1000 contre joueur heuristic_aggressive
# Games  : 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]
# Joueur montecarlo_1000 contre joueur heuristic_defensive
# Games  : 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# Joueur montecarlo_1000 contre joueur heuristic_mobility
# Games  : 100%|██████████| 100/100 [01:36<00:00,  1.04it/s]
# Joueur montecarlo_1000 contre joueur heuristic_positional
# Games  : 100%|██████████| 100/100 [01:29<00:00,  1.12it/s]
# Joueur montecarlo_1000 contre joueur heuristic_2lookahead_regular
# Games  : 100%|██████████| 100/100 [01:46<00:00,  1.07s/it]
# Joueur montecarlo_1000 contre joueur heuristic_2lookahead_aggressive
# Games  : 100%|██████████| 100/100 [01:31<00:00,  1.10it/s]
# Joueur montecarlo_1000 contre joueur heuristic_2lookahead_defensive
# Games  : 100%|██████████| 100/100 [02:23<00:00,  1.43s/it]
# Joueur montecarlo_1000 contre joueur heuristic_2lookahead_mobility
# Games  : 100%|██████████| 100/100 [02:25<00:00,  1.46s/it]
# Joueur montecarlo_1000 contre joueur heuristic_2lookahead_positional
# Games  : 100%|██████████| 100/100 [01:45<00:00,  1.06s/it]
# Joueur montecarlo_1000 contre joueur heuristic_3lookahead_regular
# Games  : 100%|██████████| 100/100 [04:58<00:00,  2.98s/it]
# Joueur montecarlo_1000 contre joueur heuristic_3lookahead_aggressive
# Games  : 100%|██████████| 100/100 [02:58<00:00,  1.78s/it]
# Joueur montecarlo_1000 contre joueur heuristic_3lookahead_defensive
# Games  : 100%|██████████| 100/100 [02:53<00:00,  1.74s/it]
# Joueur montecarlo_1000 contre joueur heuristic_3lookahead_mobility
# Games  : 100%|██████████| 100/100 [04:50<00:00,  2.91s/it]
# Joueur montecarlo_1000 contre joueur heuristic_3lookahead_positional
# Games  : 100%|██████████| 100/100 [03:42<00:00,  2.23s/it]
# Joueur montecarlo_1000 contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [2:38:03<00:00, 94.84s/it]
# Joueur montecarlo_1000 contre joueur cnn_v2_dropout_large
# Games  : 100%|██████████| 100/100 [03:22<00:00,  2.03s/it]
# Joueur montecarlo_2000 contre joueur random
# Games  : 100%|██████████| 100/100 [17:58<00:00, 10.78s/it]
# Joueur montecarlo_2000 contre joueur heuristic_regular
# Games  : 100%|██████████| 100/100 [05:03<00:00,  3.04s/it]
# Joueur montecarlo_2000 contre joueur heuristic_aggressive
# Games  : 100%|██████████| 100/100 [04:16<00:00,  2.57s/it]
# Joueur montecarlo_2000 contre joueur heuristic_defensive
# Games  : 100%|██████████| 100/100 [04:18<00:00,  2.58s/it]
# Joueur montecarlo_2000 contre joueur heuristic_mobility
# Games  : 100%|██████████| 100/100 [04:16<00:00,  2.57s/it]
# Joueur montecarlo_2000 contre joueur heuristic_positional
# Games  : 100%|██████████| 100/100 [04:26<00:00,  2.67s/it]
# Joueur montecarlo_2000 contre joueur heuristic_2lookahead_regular
# Games  : 100%|██████████| 100/100 [04:15<00:00,  2.55s/it]
# Joueur montecarlo_2000 contre joueur heuristic_2lookahead_aggressive
# Games  : 100%|██████████| 100/100 [03:02<00:00,  1.83s/it]
# Joueur montecarlo_2000 contre joueur heuristic_2lookahead_defensive
# Games  : 100%|██████████| 100/100 [03:10<00:00,  1.90s/it]
# Joueur montecarlo_2000 contre joueur heuristic_2lookahead_mobility
# Games  : 100%|██████████| 100/100 [03:19<00:00,  1.99s/it]
# Joueur montecarlo_2000 contre joueur heuristic_2lookahead_positional
# Games  : 100%|██████████| 100/100 [03:48<00:00,  2.29s/it]
# Joueur montecarlo_2000 contre joueur heuristic_3lookahead_regular
# Games  : 100%|██████████| 100/100 [07:09<00:00,  4.30s/it]
# Joueur montecarlo_2000 contre joueur heuristic_3lookahead_aggressive
# Games  : 100%|██████████| 100/100 [07:06<00:00,  4.26s/it]
# Joueur montecarlo_2000 contre joueur heuristic_3lookahead_defensive
# Games  : 100%|██████████| 100/100 [06:50<00:00,  4.11s/it]
# Joueur montecarlo_2000 contre joueur heuristic_3lookahead_mobility
# Games  : 100%|██████████| 100/100 [08:51<00:00,  5.31s/it]
# Joueur montecarlo_2000 contre joueur heuristic_3lookahead_positional
# Games  : 100%|██████████| 100/100 [08:08<00:00,  4.88s/it]
# Joueur montecarlo_2000 contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [1:40:16<00:00, 60.17s/it]
# Joueur montecarlo_2000 contre joueur cnn_v2_dropout_large
# Games  : 100%|██████████| 100/100 [02:36<00:00,  1.57s/it]
# Joueur cnn_v2_dropout_large contre joueur montecarlo_1000
# Games  : 100%|██████████| 100/100 [01:29<00:00,  1.12it/s]
# Joueur cnn_v2_dropout_large contre joueur montecarlo_2000
# Games  : 100%|██████████| 100/100 [02:31<00:00,  1.51s/it]

# %%
with open('resultats.pkl', 'wb') as f:
    pickle.dump(resultats, f)

# %%
#Affichage d'une heatmap de comparaison des modèles

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Construction de la matric de taux de victoires
player_names = [players[p]['name'] for p in players]
matrix = pd.DataFrame(index=player_names, columns=player_names, dtype=float)

for p1 in players:
    p1_name = players[p1]['name']
    for p2 in players:
        p2_name = players[p2]['name']
        if p1 != p2:
            matrix.loc[p1_name, p2_name] = float(resultats[p1][p2]['win']/100)


#Affichage de la heatmap
fig, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(
    matrix.astype(float),
    annot=True,
    fmt=".0%",
    cmap="RdYlGn",
    vmin=0,
    vmax=1,
    linewidths=0.5,
    ax=ax
)
ax.set_title("Comparaison des taux de victoire", fontsize=13)
ax.set_xlabel("Adversaire")
ax.set_ylabel("Joueur évalué")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#Calcul du taux de victoire moyen

#Préparation des données
graphdata = pd.DataFrame(index=player_names, columns=["player", "avg_score", "color"])
for p in players:
    total = sum(resultats[p][p2]['win'] for p2 in resultats[p])/len(resultats[p])
    p_name = players[p]['name']
    graphdata.loc[p_name, 'player'] = p_name
    graphdata.loc[p_name, 'avg_score'] = total
    graphdata.loc[p_name, 'color'] = type_colors[players[p]['type']]

plt.figure(figsize=(12, 5))

graphdata = graphdata.sort_values('avg_score', ascending=True)

plt.barh(graphdata['player'], graphdata['avg_score'], color=graphdata['color'], alpha=1)
plt.xlabel('Win-rate')
plt.ylabel('Joueur évalué')
plt.title('Performances des joueurs de référence entre eux')
plt.xlim(0, 100)  # Adapter selon vos valeurs
plt.grid(axis='x', alpha=0.3)


plt.tight_layout()
plt.show()

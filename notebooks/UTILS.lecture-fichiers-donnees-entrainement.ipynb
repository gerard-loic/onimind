# %%
import sys
sys.path.append('../onitama/')

from trainer import RegularDataTrainer
from pathlib import Path
# Out:
# 2026-03-15 10:06:30.689907: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-15 10:06:30.696588: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-15 10:06:30.911526: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
consolided = []
SRC_FOLDER = "../data/"

# %%
files = list(Path(SRC_FOLDER).glob("*actions.pkl"))
for file in files:
    if "3" in file.name:
        data = RegularDataTrainer.getTrainedData(filepath=f"../data/{file}")

        line = {
            'filename' : file.name,
            'nb_exp' : len(data),
            'nb_games' : float(len(data)/21)
        }
        consolided.append(line)

# %%
consolided
# Out:
# [{'filename': 'training-data-heuristic-vs-laheuristic3-2-actions.pkl',
#   'nb_exp': 49526,
#   'nb_games': 1650.8666666666666},
#  {'filename': 'distil-CNNLookAhead-vs-CNNLookAhead-actions.pkl',
#   'nb_exp': 31988,
#   'nb_games': 1066.2666666666667},
#  {'filename': 'training-data-random-vs-laheuristic3-actions.pkl',
#   'nb_exp': 36283,
#   'nb_games': 1209.4333333333334},
#  {'filename': 'training-data-laheuristic2-vs-laheuristic3-actions.pkl',
#   'nb_exp': 57544,
#   'nb_games': 1918.1333333333334},
#  {'filename': 'agressive2-vs-defensive2-actions.pkl',
#   'nb_exp': 68426,
#   'nb_games': 2280.866666666667},
#  {'filename': 'agressive2-vs-mobility2-actions.pkl',
#   'nb_exp': 43313,
#   'nb_games': 1443.7666666666667},
#  {'filename': 'training-data-heuristic-vs-laheuristic2-actions.pkl',
#   'nb_exp': 34147,
#   'nb_games': 1138.2333333333333},
#  {'filename': 'training-data-heuristic-vs-laheuristic3-actions.pkl',
#   'nb_exp': 48787,
#   'nb_games': 1626.2333333333333},
# ...

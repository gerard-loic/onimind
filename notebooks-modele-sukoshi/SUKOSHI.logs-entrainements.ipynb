# %% [markdown]
# ## Supervisé
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pré-entraînement tête
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Entraînement PPO (1)
#
# | Paramètre | Valeur |
# | --------- | ------ |
# | N_ITERATIONS | 750 |
# | N_GAMES | 128 |
# | N_EPOCHS | 4 |
# | MINIBATCH_SIZE | 64 |
# | LEARNING_RATE | 1e-4 |
# | CLIP_EPSILON | 0.1 |
# | VALUE_COEF | 0.5 |
# | ENTROPY_COEF | 0.01 |
# | GAMMA | 0.99 |
# | LAM | 0.95 |
# | Adv. LA1 | 30% |
# | Adv. LA2 | 20% |
# | Adv. LA3 | 0% |
# | Self-play | 40% |

# %% [markdown]
# ![image.png](attachment:image.png)

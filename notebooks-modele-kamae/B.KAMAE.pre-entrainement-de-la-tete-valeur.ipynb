# %% [markdown]
# # Pré-entraînement de la Value Head
#
# Ce notebook pré-entraîne uniquement la value head du réseau, en gardant le tronc et la policy head gelés.

# %%
import sys
sys.path.append('../onitama/')

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from IPython.display import clear_output
from tqdm import tqdm

from dl_players_v6 import CNNPlayer_v6
from game import Game
from players import LookAheadHeuristicPlayer
from ppo import PPOBuffer

# %matplotlib inline
# Out:
# 2026-04-16 11:12:09.569703: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-16 11:12:09.569986: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-16 11:12:09.614424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-16 11:12:10.488639: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-16 11:12:10.488972: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ## Configuration

# %%
#Configuration
dst_model_name = "kamae-training-value-head"
PRETRAINED_WEIGHTS = '../models/weights/Kamae2.weights.h5'
SAVE_PATH = f"../models/training/{dst_model_name}.weights.h5"

N_ITERATIONS  = 100   # Nombre d'itérations collect + update
N_GAMES       = 128    # Parties par itération
N_EPOCHS      = 4     # Passes sur les données collectées
MINIBATCH_SIZE = 64
LEARNING_RATE = 3e-4  
# lam=1.0 + gamma=1.0 : returns = outcome final pur (±1), sans bootstrap sur V(s)
GAMMA = 1.0
LAM   = 1.0

SAVE_EVERY = 20
PLOT_EVERY = 1

# %% [markdown]
# ## Inisitialisation du modèle

# %%
#Initialisation du modèle

p1 = CNNPlayer_v6()
p1.load_weights(PRETRAINED_WEIGHTS)


# Geler tronc + policy head
p1.freeze_trunk()
for layer in p1.policy_layers:
    layer.trainable = False

# Vérification
total     = len(p1.model.layers)
trainable = sum(1 for l in p1.model.layers if l.trainable)
frozen    = total - trainable

print(f"Layers total     : {total}")
print(f"Layers gelés     : {frozen}  (trunk + policy)")
print(f"Layers actifs    : {trainable}  (value head dont value_adapter)")
print()
print(f"Variables entraînables : {len(p1.model.trainable_variables)}")
print()
print("Layers entraînables :")
for l in p1.model.layers:
    if l.trainable and l.get_weights():
        print(f"  {l.name}")

optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# 50% max_depth=2, 50% max_depth=1
p2_opponent = [
    LookAheadHeuristicPlayer(heuristic_function="heuristic_defensive", max_depth=1)
]

print("\nModèle prêt.")
# Out:
# 2026-04-16 11:12:18.514566: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Gelé 44 layers du tronc
# Layers total     : 60
# Layers gelés     : 50  (trunk + policy)
# Layers actifs    : 10  (value head dont value_adapter)
#
# Variables entraînables : 12
#
# Layers entraînables :
#   value_adapter_conv
#   value_adapter_bn
#   value_conv
#   value_bn
#   value_dense1
#   value_output
#
# Modèle prêt.

# %% [markdown]
# ## Fonctions de collecte et d'entraînement

# %%
#Jour n_games parties et remplit le buffer
def collect(player, opponent, n_games, gamma, lam):
    #Active l'apprentissage PPO pour jouer de manière stochastique
    player.setPPOTraining(True)

    buffer = PPOBuffer(p1=player, p2=opponent[0] if isinstance(opponent, list) else opponent, gamma=gamma, lam=lam)
    wins = losses = 0

    #On joue les parties
    for _ in tqdm(range(n_games), desc="collect"):
        opp = np.random.choice(opponent) if isinstance(opponent, list) else opponent
        game = Game(player_one=player, player_two=opp, verbose=False, trainer=buffer)
        result = game.playGame(return_winner=True)
        if result == 1:
            wins += 1
        elif result == 2:
            losses += 1

    #Désactive l'apprentissage PPO
    player.setPPOTraining(False)
    data = buffer.get()
    return data, wins, losses


#Entraîne la tête de valeur uniquement
def update_value_head(player, data, n_epochs, minibatch_size, optimizer):
    n = len(data['states'])
    value_losses = []

    #On passe les données n_epochs fois
    for _ in range(n_epochs):
        indices = np.random.permutation(n)
        for start in range(0, n, minibatch_size):
            batch_idx = indices[start:start + minibatch_size]
            states  = tf.constant(data['states'][batch_idx])
            returns = tf.constant(data['returns'][batch_idx])

            with tf.GradientTape() as tape:
                _, values = player.model(states, training=True)
                values = tf.squeeze(values, axis=-1)
                value_loss = tf.reduce_mean(tf.square(values - returns))

            # model.trainable_variables = value head seulement (trunk + policy gelés)
            grads = tape.gradient(value_loss, player.model.trainable_variables)
            grads, _ = tf.clip_by_global_norm(grads, 1.0)
            optimizer.apply_gradients(zip(grads, player.model.trainable_variables))
            value_losses.append(float(value_loss))

    return np.mean(value_losses)


#Calcul de MSE différent en début et fin de trajectoire
def compute_mse_by_position(player, data):
    returns = data['returns']
    states  = data['states']
    n = len(returns)

    positions = np.zeros(n, dtype=np.float32)
    traj_start = 0
    for i in range(1, n + 1):
        if i == n or np.sign(returns[i]) != np.sign(returns[traj_start]):
            length = i - traj_start
            positions[traj_start:i] = np.linspace(0, 1, length) if length > 1 else [0.5]
            traj_start = i

    # Prédictions V(s) sur tout le batch
    _, v_all = player.model(tf.constant(states, dtype=tf.float32), training=False)
    v_all = tf.squeeze(v_all).numpy()

    early_mask = positions < 0.33
    late_mask  = positions > 0.67

    mse_early = float(np.mean((v_all[early_mask] - returns[early_mask])**2)) if early_mask.any() else float('nan')
    mse_late  = float(np.mean((v_all[late_mask]  - returns[late_mask])**2))  if late_mask.any()  else float('nan')

    return mse_early, mse_late

# %% [markdown]
# # Entraînement

# %%
#Boucle d'entraînement

history = {
    'value_loss': [],
    'wins': [],
    'losses': [],
    'transitions': [],
    'value_mean': [],
    'value_std': [],
    'mse_early': [],
    'mse_late': [],
}

def plot(iteration):
    iters = list(range(1, iteration + 1))

    def moving_avg(values, w=10):
        if len(values) < w:
            return None, None
        kernel = np.ones(w) / w
        return list(range(w, len(values) + 1)), np.convolve(values, kernel, mode='valid')

    clear_output(wait=True)
    fig = plt.figure(figsize=(16, 8))
    fig.suptitle(f'Pré-entraînement Value Head — Itération {iteration}/{N_ITERATIONS}',
                 fontsize=13, fontweight='bold')
    gs = gridspec.GridSpec(2, 3, figure=fig, hspace=0.45, wspace=0.35)

    # Affichge évolution de la value loss
    ax1 = fig.add_subplot(gs[0, 0])
    ax1.plot(iters, history['value_loss'], color='darkorange', alpha=0.4, linewidth=1)
    xi, ys = moving_avg(history['value_loss'])
    if xi:
        ax1.plot(xi, ys, color='darkorange', linewidth=2)
    ax1.set_title('Value Loss (MSE)')
    ax1.set_xlabel('Itération')
    ax1.set_ylabel('MSE')
    ax1.legend(fontsize=8)
    ax1.grid(True, alpha=0.3)

    #Aff distribution des sorties de la valeur de l'état
    ax2 = fig.add_subplot(gs[0, 1])
    ax2.plot(iters, history['value_mean'], color='steelblue', linewidth=2, label='Moyenne V(s)')
    v_mean = np.array(history['value_mean'])
    v_std  = np.array(history['value_std'])
    ax2.fill_between(iters, v_mean - v_std, v_mean + v_std, alpha=0.2, color='steelblue')
    ax2.axhline(0, color='gray', linestyle=':', linewidth=1)
    ax2.set_title('Distribution des sorties V(s)')
    ax2.set_xlabel('Itération')
    ax2.set_ylabel('V(s)')
    ax2.set_ylim(-1.1, 1.1)
    ax2.legend(fontsize=8)
    ax2.grid(True, alpha=0.3)

    #Résultats parties
    ax3 = fig.add_subplot(gs[0, 2])
    wins   = np.array(history['wins'])
    losses = np.array(history['losses'])
    total  = wins + losses
    safe   = np.where(total == 0, 1, total)
    ax3.plot(iters, wins / safe * 100, color='#4caf50', linewidth=1.5, label='Victoires')
    ax3.plot(iters, losses / safe * 100, color='#f44336', linewidth=1.5, label='Défaites')
    ax3.axhline(50, color='gray', linestyle=':', alpha=0.5)
    ax3.set_title('Résultats parties (%)')
    ax3.set_xlabel('Itération')
    ax3.set_ylabel('%')
    ax3.set_ylim(0, 100)
    ax3.legend(fontsize=8)
    ax3.grid(True, alpha=0.3)

    #Nb de Transitions collectées (si ça augmente = mauvais signe)
    ax4 = fig.add_subplot(gs[1, 0])
    ax4.bar(iters, history['transitions'], color='slategray', alpha=0.7, width=0.8)
    ax4.set_title('Transitions collectées')
    ax4.set_xlabel('Itération')
    ax4.set_ylabel('Nombre')
    ax4.grid(True, alpha=0.3, axis='y')

    #MSE début vs fin de trajectoire
    ax5 = fig.add_subplot(gs[1, 1])
    ax5.plot(iters, history['mse_early'], color='tomato',    linewidth=1.5, label='Début partie (pos < 33%)')
    ax5.plot(iters, history['mse_late'],  color='mediumseagreen', linewidth=1.5, label='Fin partie (pos > 67%)')
    xi_e, ys_e = moving_avg(history['mse_early'])
    xi_l, ys_l = moving_avg(history['mse_late'])
    if xi_e:
        ax5.plot(xi_e, ys_e, color='tomato',         linewidth=2.5, alpha=0.6)
        ax5.plot(xi_l, ys_l, color='mediumseagreen', linewidth=2.5, alpha=0.6)
    ax5.set_title('MSE début vs fin de partie')
    ax5.set_xlabel('Itération')
    ax5.set_ylabel('MSE')
    ax5.legend(fontsize=8)
    ax5.grid(True, alpha=0.3)

    plt.show()


for i in range(N_ITERATIONS):
    #Collecte des données de jeu
    data, wins, losses = collect(p1, p2_opponent, N_GAMES, GAMMA, LAM)

    #Stats sur les sorties V(s) du batch
    states_sample = tf.constant(data['states'][:256])
    _, v_sample = p1.model(states_sample, training=False)
    v_sample = v_sample.numpy().flatten()

    #MSE début vs fin de trajectoire (avant update)
    mse_early, mse_late = compute_mse_by_position(p1, data)

    #ise à jour value head
    v_loss = update_value_head(p1, data, N_EPOCHS, MINIBATCH_SIZE, optimizer)

    #Historique
    history['value_loss'].append(v_loss)
    history['wins'].append(wins)
    history['losses'].append(losses)
    history['transitions'].append(len(data['states']))
    history['value_mean'].append(float(np.mean(v_sample)))
    history['value_std'].append(float(np.std(v_sample)))
    history['mse_early'].append(mse_early)
    history['mse_late'].append(mse_late)

    print(f"[{i+1:4d}/{N_ITERATIONS}] "
          f"transitions={len(data['states'])} | "
          f"W/L={wins}/{losses} | "
          f"v_loss={v_loss:.4f} | "
          f"V(s) moy={np.mean(v_sample):.3f} ± {np.std(v_sample):.3f} | "
          f"MSE early={mse_early:.4f} late={mse_late:.4f}")

    if (i + 1) % PLOT_EVERY == 0:
        plot(i + 1)

    if SAVE_PATH and (i + 1) % SAVE_EVERY == 0:
        path = f"{SAVE_PATH}_iter{i+1}.weights.h5"
        p1.save_weights(path)
        print(f"  → Sauvegardé : {path}")

print("\nPré-entraînement value head terminé !")
# Out:
# collect:  52%|█████▏    | 66/128 [00:12<00:11,  5.46it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 99
#      94     plt.show()
#      97 for i in range(N_ITERATIONS):
#      98     #Collecte des données de jeu
# ---> 99     data, wins, losses = collect(p1, p2_opponent, N_GAMES, GAMMA, LAM)
#     101     #Stats sur les sorties V(s) du batch
#     102     states_sample = tf.constant(data['states'][:256])
#
# Cell In[5], line 13, in collect(player, opponent, n_games, gamma, lam)
#      11 opp = np.random.choice(opponent) if isinstance(opponent, list) else opponent
#      12 game = Game(player_one=player, player_two=opp, verbose=False, trainer=buffer)
# ---> 13 result = game.playGame(return_winner=True)
#      14 if result == 1:
#      15     wins += 1
#
# File ~/python/onitama-rl/notebooks-modele-kamae/../onitama/game.py:116, in Game.playGame(self, return_winner, max_turns, play_once_only, return_move)
#     114 #On fait jouer le joueur
#     115 ts_before = int(time.time() * 1000)
# --> 116 result = self.current_player.play(board=self.board)
#     117 #Dans le cas d'un entraînement PPO, retourne 3 ou 4 valeurs
#     118 if type(result) is tuple:
#
# File ~/python/onitama-rl/notebooks-modele-kamae/../onitama/dl_players_v6.py:111, in CNNPlayer_v6.play(self, board)
#     108     return None
#     110 #On effectue la prédiction
# --> 111 policy_logits, value = self.predict(state)
#     112 # value = float entre -1 (position perdue) et +1 (position gagnée)
#     113 policy_logits = np.array(policy_logits).flatten()  # (1300,)
#
# File ~/python/onitama-rl/notebooks-modele-kamae/../onitama/dl_players_v6.py:173, in CNNPlayer_v6.predict(self, state)
#     170 if len(state.shape) == 3:
#     171     state = tf.expand_dims(state, 0)
# --> 173 return self._predict_compiled(tf.cast(state, tf.float32))
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/python/onitama-rl/.venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

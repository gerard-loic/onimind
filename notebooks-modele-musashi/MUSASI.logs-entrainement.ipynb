# %% [markdown]
# # Supervisé
#
# ![image.png](attachment:image.png)
#
# ## Entraînement PPO
#
# | Paramètre | Valeur |
# | --------- | ------ |
# | N_ITERATIONS | 500 |
# | N_GAMES | 64 |
# | N_EPOCHS | 4 |
# | MINIBATCH_SIZE | 64 |
# | LEARNING_RATE | 1e-4 |
# | CLIP_EPSILON | 0.1 |
# | VALUE_COEF | 0.5 |
# | ENTROPY_COEF | 0.005 |
# | GAMMA | 0.99 |
# | LAM | 0.95 |
# | Adv. LA1 | 10% |
# | Adv. LA2 | 40% |
# | Adv. LA3 | 0% |
# | Self-play | 50% |

# %% [markdown]
# ![image.png](attachment:image.png)
